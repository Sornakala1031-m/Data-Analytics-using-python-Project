# %% [markdown]
# <a href="https://colab.research.google.com/github/Sornakala1031-m/Data-Analytics-using-python-Project/blob/main/day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = [10,10,10,10,10]
50/5
# Out:
# 10.0

# %%
import pandas as pd
data = pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = pd.Series(
    [100,200,300,400,500],
    index = ["Xiao zhan","Zhao lusi","Wang yi bo","Bailu","Chen zheyuan"]
    )
print(data)
# Out:
# Xiao zhan       100
# Zhao lusi       200
# Wang yi bo      300
# Bailu           400
# Chen zheyuan    500
# dtype: int64

# %%
import pandas as pd
data={
     "Name":["Yizhan","Dorami"],
     "Age":[35,26],
     "Department":["CEO","Crime department"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age        Department
# 0  Yizhan   35               CEO
# 1  Dorami   26  Crime department

# %%
import pandas as pd
employee = {
    "ID":[101,102,103],
    "Name":["Ayan","Cha mugi","Hiro"],
    "Salary":[60000,50500,50000]
}
df = pd.DataFrame(employee)
print(df)
# Out:
#     ID      Name  Salary
# 0  101      Ayan   60000
# 1  102  Cha mugi   50500
# 2  103      Hiro   50000

# %%
import pandas as pd
data = {
     "Product":["Laptop","Mobile","Tab"],
     "Sales":[50000,30000,25000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Product  Sales
# 0  Laptop  50000
# 1  Mobile  30000
# 2     Tab  25000

# %%
import pandas as pd
data = {
     "Product":["Laptop","Mobile","Tab"],
     "Sales":[50000,30000,25000]
}
df=pd.DataFrame(data)
print(df)

print("Total sales =",df["Sales"].sum())
print("Average Sales =",df["Sales"].mean())
print("Highest sales =",df["Sales"].max())
# Out:
#   Product  Sales
# 0  Laptop  50000
# 1  Mobile  30000
# 2     Tab  25000
# Total sales = 105000
# Average Sales = 35000.0
# Highest sales = 50000
