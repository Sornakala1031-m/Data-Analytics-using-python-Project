# %% [markdown]
# <a href="https://colab.research.google.com/github/Sornakala1031-m/Data-Analytics-using-python-Project/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([1,2,3,4,5,6])
new_arr = arr.reshape(2,3)
print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
marks = np.array([10,20,30,40])
average = np.mean(marks)
print(average)
# Out:
# 25.0

# %%
import numpy as np
scores = np.array([78,85,92,67,88])

total = np.sum(scores)
average = np.mean(scores)
highest = np.max(scores)
lowest = np.min(scores)

print("student scores:",scores)
print("total marks:",total)
print("average marks:",average)
print("highest marks:",highest)
print("lowest mark:",lowest)
# Out:
# student scores: [78 85 92 67 88]
# total marks: 410
# average marks: 82.0
# highest marks: 92
# lowest mark: 67

# %%
import numpy as np
sales = np.array([12000,15000,18000,14000,20000])

total_sales = np.sum(sales)
average_sales = np.mean(sales)
highest_sales = np.max(sales)
lowest_sales = np.min(sales)

print("monthly sales:",sales)
print("total sales:",total_sales)
print("average sales:",average_sales)
print("highest sales:",highest_sales)
print("lowest sales:",lowest_sales)
# Out:
# monthly sales: [12000 15000 18000 14000 20000]
# total sales: 79000
# average sales: 15800.0
# highest sales: 20000
# lowest sales: 12000

# %%
import numpy as np
salary = np.array([10000,20000,30000,40000,50000])
med = np.median(salary)
print(med)
# Out:
# 30000.0
